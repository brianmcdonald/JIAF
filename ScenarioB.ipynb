# %%
import pandas as pd

# %% [markdown]
# ### Steps:
# - Ask user for: ISO code of target country; admin level of analysis; population groups; number of indicators
# - Request population statistics from COD API and create file with tab called baseline population
# - Add template tabs for indicators, sector data and data entry, population groups disaggregation and output template file
#
#
# - Create long data from data entry data
# - Calculate severity and min calculated PiN in long data
# - Calculate mean of max 40% to calculate per area severity
# - For each admin unit, calculate min pop in the severity class (25% of population or 100% if severity one), JIAF PiN estimate (>25% if severity is 3, 4 or 5, >25% is 1 or 2) and place alongside sector PiNs and critical indicator PiNs

# %%
long_data = pd.read_excel('ScenarioBtest.xlsx', sheet_name='Step 4-Long Data')
long_data.drop(columns=['Unnamed: 0']).head(5)
# Out:
#    Row ID  Key ID Admin 2 P-Code              Key  Indicator Number  \
# 0       1       1           AF01  AF01-All_Others                 1
# 1       2       2           AF02  AF02-All_Others                 1
# 2       3       3           AF03  AF03-All_Others                 1
# 3       4       4           AF04  AF04-All_Others                 1
# 4       5       5           AF05  AF05-All_Others                 1
#
#           Indicator Pillar           Indicator Sub-Pillar  \
# 0  Humanitarian Conditions  Physical and mental wellbeing
# 1  Humanitarian Conditions  Physical and mental wellbeing
# 2  Humanitarian Conditions  Physical and mental wellbeing
# 3  Humanitarian Conditions  Physical and mental wellbeing
# 4  Humanitarian Conditions  Physical and mental wellbeing
#
#                                       Indicator Text Indicator Class  \
# 0  % of  households with at least one member with...          Degree
# ...
